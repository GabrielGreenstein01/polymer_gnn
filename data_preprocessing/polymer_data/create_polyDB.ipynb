# %%
import pandas as pd
import numpy as np
import re

# %%
df1 = pd.read_csv('formatted_data/rd1_formatted.csv')
df2 = pd.read_csv('formatted_data/rd2_formatted.csv')
df3 = pd.read_csv('formatted_data/rd3_formatted.csv')

# %%
stacked_df = pd.concat([df1, df2, df3], ignore_index=True).dropna(axis=1)
stacked_df
# Out:
#     poly_ID                               monomers  \
# 0         1                    ['Tma', 'Ni', 'Mo']
# 1         2                   ['Tma', 'Ni', 'Mep']
# 2         3                   ['Tma', 'Phe', 'Mo']
# 3         4                  ['Tma', 'Phe', 'Mep']
# 4         5                    ['Tma', 'Do', 'Mo']
# 5         6                   ['Tma', 'Do', 'Mep']
# 6         7                    ['Tma', 'Ni', 'Mo']
# 7         8                   ['Tma', 'Ni', 'Mep']
# 8         9                   ['Tma', 'Phe', 'Mo']
# 9        10                  ['Tma', 'Phe', 'Mep']
# 10       11                    ['Tma', 'Do', 'Mo']
# 11       12                   ['Tma', 'Do', 'Mep']
# 12       13                    ['Tma', 'Ni', 'Mo']
# 13       14                   ['Tma', 'Ni', 'Mep']
# 14       15                   ['Tma', 'Phe', 'Mo']
# 15       16                  ['Tma', 'Phe', 'Mep']
# 16       17                    ['Tma', 'Do', 'Mo']
# 17       18                   ['Tma', 'Do', 'Mep']
# 18       19                  ['Tma', 'Bam', 'Mep']
# 19       20                 ['Tma', 'Bmam', 'Mep']
# 20       21                  ['Tma', 'Tmb', 'Mep']
# 21       22                  ['Tma', 'Oct', 'Mep']
# 22       23                 ['Tma', 'Olam', 'Mep']
# 23       24                          ['Tma', 'Do']
# 24       25                  ['Aeg', 'Mo', 'Olam']
# 25       26                   ['Tma', 'Ni', 'Phe']
# 26       27                  ['Tma', 'Bam', 'Oct']
# 27       28            ['Tma', 'Mo', 'Phe', 'Oct']
# 28       29          ['Tma', 'Aeg', 'Phe', 'Olam']
# 29       30            ['Tma', 'Aeg', 'Ni', 'Tmb']
# 30       31           ['Tma', 'Mo', 'Phe', 'Olam']
# 31       32            ['Tma', 'Aeg', 'Mo', 'Tmb']
# 32       33     ['Tma', 'Aeg', 'Mo', 'Ni', 'Olam']
# 33       34                          ['Tma', 'Do']
# 34       35                   ['Tma', 'Phe', 'Do']
# 35       36          ['Tma', 'Aeg', 'Phe', 'Olam']
# 36       37             ['Tma', 'Mep', 'Ni', 'Do']
# 37       38           ['Tma', 'Mo', 'Phe', 'Olam']
# 38       39             ['Tma', 'Mo', 'Phe', 'Do']
# 39       40           ['Tma', 'Aeg', 'Oct', 'Tmb']
# 40       41      ['Tma', 'Mo', 'Mep', 'Do', 'Bam']
# 41       42     ['Tma', 'Aeg', 'Mo', 'Phe', 'Bam']
# 42       43  ['Tma', 'Mep', 'Phe', 'Olam', 'Bmam']
#
#                                            mon_SMILES      mon_class_wt_%  \
# 0   ['C[N+](C)(C)CCCNC(=O)C=C', 'CC(C)NC(=O)C=C', ...  [59.1, 30.7, 10.2]
# 1   ['C[N+](C)(C)CCCNC(=O)C=C', 'CC(C)NC(=O)C=C', ...  [59.1, 30.7, 10.2]
# 2   ['C[N+](C)(C)CCCNC(=O)C=C', 'C=CC(=O)Nc1ccccc1...  [59.1, 30.7, 10.2]
# 3   ['C[N+](C)(C)CCCNC(=O)C=C', 'C=CC(=O)Nc1ccccc1...  [59.1, 30.7, 10.2]
# 4   ['C[N+](C)(C)CCCNC(=O)C=C', 'CCCCCCCCCCCCNC(=O...  [59.1, 30.7, 10.2]
# 5   ['C[N+](C)(C)CCCNC(=O)C=C', 'CCCCCCCCCCCCNC(=O...  [59.1, 30.7, 10.2]
# 6   ['C[N+](C)(C)CCCNC(=O)C=C', 'CC(C)NC(=O)C=C', ...   [82.7, 13.0, 4.3]
# 7   ['C[N+](C)(C)CCCNC(=O)C=C', 'CC(C)NC(=O)C=C', ...   [82.7, 13.0, 4.3]
# 8   ['C[N+](C)(C)CCCNC(=O)C=C', 'C=CC(=O)Nc1ccccc1...   [82.7, 13.0, 4.3]
# 9   ['C[N+](C)(C)CCCNC(=O)C=C', 'C=CC(=O)Nc1ccccc1...   [82.7, 13.0, 4.3]
# 10  ['C[N+](C)(C)CCCNC(=O)C=C', 'CCCCCCCCCCCCNC(=O...   [82.7, 13.0, 4.3]
# 11  ['C[N+](C)(C)CCCNC(=O)C=C', 'CCCCCCCCCCCCNC(=O...   [82.7, 13.0, 4.3]
# 12  ['C[N+](C)(C)CCCNC(=O)C=C', 'CC(C)NC(=O)C=C', ...  [59.1, 30.7, 10.2]
# 13  ['C[N+](C)(C)CCCNC(=O)C=C', 'CC(C)NC(=O)C=C', ...  [59.1, 30.7, 10.2]
# 14  ['C[N+](C)(C)CCCNC(=O)C=C', 'C=CC(=O)Nc1ccccc1...  [59.1, 30.7, 10.2]
# 15  ['C[N+](C)(C)CCCNC(=O)C=C', 'C=CC(=O)Nc1ccccc1...  [59.1, 30.7, 10.2]
# 16  ['C[N+](C)(C)CCCNC(=O)C=C', 'CCCCCCCCCCCCNC(=O...  [59.1, 30.7, 10.2]
# 17  ['C[N+](C)(C)CCCNC(=O)C=C', 'CCCCCCCCCCCCNC(=O...  [59.1, 30.7, 10.2]
# 18  ['C[N+](C)(C)CCCNC(=O)C=C', 'CCCCNC(=O)C=C', '...  [59.1, 30.7, 10.2]
# 19  ['C[N+](C)(C)CCCNC(=O)C=C', 'CCCCOCNC(=O)C=C',...  [59.1, 30.7, 10.2]
# 20  ['C[N+](C)(C)CCCNC(=O)C=C', 'CC(C)(C)CC(C)(C)N...  [59.1, 30.7, 10.2]
# 21  ['C[N+](C)(C)CCCNC(=O)C=C', 'CCCCCCCCNC(=O)C=C...  [59.1, 30.7, 10.2]
# 22  ['C[N+](C)(C)CCCNC(=O)C=C', 'CCCCCCCC/C=C\\CCC...  [59.1, 30.7, 10.2]
# 23  ['C[N+](C)(C)CCCNC(=O)C=C', 'CCCCCCCCCCCCNC(=O...   [75.0, 0.0, 25.0]
# 24  ['[Cl-].NC(=[NH2+])NCCNC(=O)C=C', 'C=CC(=O)N1C...  [10.0, 60.0, 30.0]
# 25  ['C[N+](C)(C)CCCNC(=O)C=C', 'CC(C)NC(=O)C=C', ...   [55.0, 0.0, 45.0]
# 26  ['C[N+](C)(C)CCCNC(=O)C=C', 'CCCCOCNC(=O)C=C',...   [55.0, 0.0, 45.0]
# 27  ['C[N+](C)(C)CCCNC(=O)C=C', 'C=CC(=O)N1CCOCC1'...  [17.0, 55.0, 28.0]
# 28  ['C[N+](C)(C)CCCNC(=O)C=C', '[Cl-].NC(=[NH2+])...   [55.0, 0.0, 45.0]
# 29  ['C[N+](C)(C)CCCNC(=O)C=C', '[Cl-].NC(=[NH2+])...   [55.0, 0.0, 45.0]
# 30  ['C[N+](C)(C)CCCNC(=O)C=C', 'C=CC(=O)N1CCOCC1'...  [35.0, 20.0, 45.0]
# 31  ['C[N+](C)(C)CCCNC(=O)C=C', '[Cl-].NC(=[NH2+])...   [55.0, 37.0, 8.0]
# 32  ['C[N+](C)(C)CCCNC(=O)C=C', '[Cl-].NC(=[NH2+])...   [50.0, 5.0, 45.0]
# 33  ['C[N+](C)(C)CCCNC(=O)C=C', 'CCCCCCCCCCCCNC(=O...   [90.0, 0.0, 10.0]
# 34  ['C[N+](C)(C)CCCNC(=O)C=C', 'C=CC(=O)Nc1ccccc1...   [80.0, 0.0, 20.0]
# 35  ['C[N+](C)(C)CCCNC(=O)C=C', '[Cl-].NC(=[NH2+])...   [90.0, 0.0, 10.0]
# 36  ['C[N+](C)(C)CCCNC(=O)C=C', 'C=CC(=O)NCCCOC', ...   [70.0, 5.0, 25.0]
# 37  ['C[N+](C)(C)CCCNC(=O)C=C', 'C=CC(=O)N1CCOCC1'...  [60.0, 15.0, 25.0]
# 38  ['C[N+](C)(C)CCCNC(=O)C=C', 'C=CC(=O)N1CCOCC1'...  [40.0, 50.0, 10.0]
# 39  ['C[N+](C)(C)CCCNC(=O)C=C', '[Cl-].NC(=[NH2+])...   [80.0, 0.0, 20.0]
# 40  ['C[N+](C)(C)CCCNC(=O)C=C', 'C=CC(=O)N1CCOCC1'...  [65.0, 25.0, 10.0]
# 41  ['C[N+](C)(C)CCCNC(=O)C=C', '[Cl-].NC(=[NH2+])...  [30.0, 25.0, 45.0]
# 42  ['C[N+](C)(C)CCCNC(=O)C=C', 'C=CC(=O)NCCCOC', ...   [70.0, 5.0, 25.0]
#
#                                  mon_mol_distribution   DP MIC_ecoli
# 0   [0.4542123849646637, 0.43100113585911337, 0.11...   70      >512
# 1   [0.4549454859354751, 0.43169677376239013, 0.11...   70      >512
# 2   [0.5044570496588803, 0.368058869011033, 0.1274...   70       256
# 3   [0.5053614730538734, 0.3687187488800791, 0.125...   70       256
# 4   [0.5878058277488345, 0.2636465684428655, 0.148...   70       128
# 5   [0.5890341712713527, 0.2641975132264877, 0.146...   70       128
# 6   [0.7335234220883662, 0.21063007227554228, 0.05...   70      >512
# 7   [0.7340989472357222, 0.2107953333970466, 0.055...   70      >512
# 8   [0.771054659625125, 0.17024140932398385, 0.058...   70      >512
# 9   [0.77169061127758, 0.17038182129637044, 0.0579...   70      >512
# 10  [0.8251748414307326, 0.1120008096186611, 0.062...   70   256-512
# 11  [0.8259032429910733, 0.11209967541096302, 0.06...   70       256
# 12  [0.4542123849646637, 0.43100113585911337, 0.11...  115      >512
# 13  [0.4549454859354751, 0.43169677376239013, 0.11...  115      >512
# 14  [0.5044570496588803, 0.368058869011033, 0.1274...  115   256-512
# 15  [0.5053614730538734, 0.3687187488800791, 0.125...  115       256
# 16  [0.5878058277488345, 0.2636465684428655, 0.148...  115       128
# 17  [0.5890341712713527, 0.2641975132264877, 0.146...  115       128
# 18  [0.4776777673797556, 0.4033003410382325, 0.119...   70      >512
# 19  [0.5175485588976436, 0.3534950343525946, 0.128...   70       256
# 20  [0.5449589958950783, 0.31925480061075623, 0.13...   70        64
# 21  [0.5449589958950783, 0.31925480061075623, 0.13...   70   128-256
# 22  [0.6315666917027046, 0.21106726063929626, 0.15...   70       128
# 23                           [0.77650798, 0.22349202]   70        64
# 24               [0.09101843, 0.74525889, 0.16372269]   70      >512
# 25               [0.42715473, 0.35467542, 0.21816985]   70      >512
# 26               [0.43771601, 0.51740712, 0.04487686]   70        32
# 27    [0.12548129, 0.5944452, 0.23845152, 0.04162198]   70      >512
# 28   [0.45042781, 0.10740022, 0.28118029, 0.16099169]   70       128
# 29   [0.26581183, 0.16297791, 0.48555995, 0.08565032]   70        64
# 30    [0.29196197, 0.24429091, 0.4100799, 0.05366721]   70       128
# 31    [0.3181497, 0.15271768, 0.45359547, 0.07553715]   70       256
# 32  [0.26930237, 0.19263775, 0.06572158, 0.3279574...   70       128
# 33                           [0.91245961, 0.08754039]   70       256
# 34               [0.75911596, 0.19991786, 0.04096618]   70       256
# 35   [0.84489248, 0.05332674, 0.06980632, 0.03197446]   70       128
# 36   [0.59286915, 0.06113782, 0.30942782, 0.03656522]   70       256
# 37   [0.52969823, 0.19390437, 0.24799873, 0.02839867]   70       128
# 38    [0.32114784, 0.58780609, 0.05638417, 0.0346619]   70      >512
# 39   [0.67773417, 0.10388523, 0.16378545, 0.05459515]   70   128-256
# 40  [0.57043705, 0.2570061, 0.06334955, 0.037888, ...   70       256
# 41  [0.18274854, 0.03921718, 0.26759191, 0.1540094...   70       512
# 42  [0.67422068, 0.06952695, 0.06764197, 0.0619661...   70        64

# %%
stacked_df.to_csv('polymer_db.csv', index=False)
