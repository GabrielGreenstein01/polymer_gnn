# %%
import pandas as pd
import numpy as np
import re
import os
os.getcwd()
# Out:
# '/Users/gabrielgreenstein/Desktop/Research/Appel Lab/GNNs/antimicrobial_GNN'

# %% [markdown]
# ## Create new "tables/immuno_[polymers].txt" File

# %%
df = pd.read_csv("shoshana_polymers/round3/wo_replacement_batch_true.csv" )
df['ID'] = df['ID'].map(lambda x: "SID" + str(x))

cols = ['ID', 'sequence', 'immunogenic']

df[cols].to_csv("shoshana_polymers/tables_poly/rd3_immuno.txt", index=False)

# %%
df
# Out:
#            ID  poly_ID                           monomers  \
# 0     SID6601       34                       ['Tma' 'Do']
# 1     SID6602       34                       ['Tma' 'Do']
# 2     SID6603       34                       ['Tma' 'Do']
# 3     SID6604       34                       ['Tma' 'Do']
# 4     SID6605       34                       ['Tma' 'Do']
# ...       ...      ...                                ...
# 1995  SID8596       43  ['Tma' 'Mep' 'Phe' 'Olam' 'Bmam']
# 1996  SID8597       43  ['Tma' 'Mep' 'Phe' 'Olam' 'Bmam']
# 1997  SID8598       43  ['Tma' 'Mep' 'Phe' 'Olam' 'Bmam']
# 1998  SID8599       43  ['Tma' 'Mep' 'Phe' 'Olam' 'Bmam']
# 1999  SID8600       43  ['Tma' 'Mep' 'Phe' 'Olam' 'Bmam']
#
#                                              mon_SMILES mon_class_wt_%  \
# 0     ['C[N+](C)(C)CCCNC(=O)C=C' 'CCCCCCCCCCCCNC(=O)...  [90.  0. 10.]
# 1     ['C[N+](C)(C)CCCNC(=O)C=C' 'CCCCCCCCCCCCNC(=O)...  [90.  0. 10.]
# 2     ['C[N+](C)(C)CCCNC(=O)C=C' 'CCCCCCCCCCCCNC(=O)...  [90.  0. 10.]
# 3     ['C[N+](C)(C)CCCNC(=O)C=C' 'CCCCCCCCCCCCNC(=O)...  [90.  0. 10.]
# 4     ['C[N+](C)(C)CCCNC(=O)C=C' 'CCCCCCCCCCCCNC(=O)...  [90.  0. 10.]
# ...                                                 ...            ...
# 1995  ['C[N+](C)(C)CCCNC(=O)C=C' 'C=CC(=O)NCCCOC' 'C...  [70.  5. 25.]
# 1996  ['C[N+](C)(C)CCCNC(=O)C=C' 'C=CC(=O)NCCCOC' 'C...  [70.  5. 25.]
# 1997  ['C[N+](C)(C)CCCNC(=O)C=C' 'C=CC(=O)NCCCOC' 'C...  [70.  5. 25.]
# 1998  ['C[N+](C)(C)CCCNC(=O)C=C' 'C=CC(=O)NCCCOC' 'C...  [70.  5. 25.]
# 1999  ['C[N+](C)(C)CCCNC(=O)C=C' 'C=CC(=O)NCCCOC' 'C...  [70.  5. 25.]
#
#                                    mon_mol_distribution  DP MIC_ecoli  \
# 0                               [0.91245961 0.08754039]  70       256
# 1                               [0.91245961 0.08754039]  70       256
# 2                               [0.91245961 0.08754039]  70       256
# 3                               [0.91245961 0.08754039]  70       256
# 4                               [0.91245961 0.08754039]  70       256
# ...                                                 ...  ..       ...
# 1995  [0.67422068 0.06952695 0.06764197 0.06196619 0...  70        64
# 1996  [0.67422068 0.06952695 0.06764197 0.06196619 0...  70        64
# 1997  [0.67422068 0.06952695 0.06764197 0.06196619 0...  70        64
# 1998  [0.67422068 0.06952695 0.06764197 0.06196619 0...  70        64
# 1999  [0.67422068 0.06952695 0.06764197 0.06196619 0...  70        64
#
#      immunogenic                                           sequence  \
# 0            Yes  DoTmaTmaTmaTmaTmaTmaTmaTmaTmaTmaTmaDoTmaTmaDoT...
# 1            Yes  TmaTmaTmaDoTmaTmaDoTmaDoTmaTmaTmaTmaTmaTmaTmaD...
# 2            Yes  TmaTmaTmaTmaTmaTmaDoTmaTmaTmaTmaTmaTmaTmaTmaTm...
# 3            Yes  TmaTmaDoTmaTmaTmaTmaTmaTmaTmaTmaTmaTmaTmaTmaTm...
# 4            Yes  TmaTmaTmaTmaTmaTmaTmaTmaTmaTmaTmaTmaTmaTmaTmaT...
# ...          ...                                                ...
# 1995         Yes  TmaTmaBmamTmaTmaMepTmaTmaTmaTmaBmamBmamTmaTmaT...
# 1996         Yes  TmaTmaTmaPheBmamTmaTmaTmaTmaBmamMepTmaBmamTmaT...
# 1997         Yes  TmaTmaTmaBmamTmaMepTmaTmaTmaTmaTmaTmaTmaTmaOla...
# 1998         Yes  BmamTmaTmaTmaTmaTmaTmaTmaPheTmaPheTmaTmaTmaTma...
# 1999         Yes  TmaBmamMepTmaTmaMepTmaTmaTmaOlamTmaBmamTmaBmam...
#
#                                        seq_mon_mol_dist
# 0                                 [0.8067014 0.1932986]
# 1                               [0.90205812 0.09794188]
# 2                                 [0.8699904 0.1300096]
# 3                               [0.95069939 0.04930061]
# 4                               [0.95069939 0.04930061]
# ...                                                 ...
# 1995  [0.76809937 0.0834561  0.02144544 0.04681947 0...
# 1996      [0.7972545  0.04247902 0.04366278 0.1166037 ]
# 1997      [0.79507293 0.06007813 0.08987802 0.05497091]
# 1998  [0.79078898 0.03100465 0.06373732 0.04638355 0...
# 1999  [0.71989169 0.05194178 0.0213557  0.0699353  0...
#
# [2000 rows x 11 columns]

# %%
df['sequence'].apply(lambda x: len(re.findall(r'[A-Z][^A-Z]*', x))).value_counts()
# Out:
# sequence
# 70    2000
# Name: count, dtype: int64

# %% [markdown]
# ## Create new "dataset/classification" Folder

# %%
# Create abridged dataset
# selected_rows = df.groupby('poly_ID').head(5)
# ids = list(selected_rows["ID"])
# sequences = list(selected_rows["sequence"])
# num_sequences = len(sequences)

# %%
# Create whole dataset
# Get list of IDs & Sequences
ids = list(df["ID"])
sequences = list(df["sequence"])
num_sequences = len(sequences)

df["sequence"].apply(lambda x: len(re.findall('[A-Z][^A-Z]*', x))).value_counts()
# Out:
# sequence
# 70    2000
# Name: count, dtype: int64

# %%
for i in range(num_sequences):

    filename = "shoshana_polymers/round3/dataset_wo_replacement_batch_true/classification/" + str(ids[i]) + "_graph.txt"

    data = []  
    data.append("MONOMERS")

    # Split sequence by capital letters (denotes different AA)
    seq = sequences[i]
    split_seq = re.findall('[A-Z][^A-Z]*', seq)
    DP = len(split_seq)

    for mon in range(DP):
        line = str(mon + 1) + " " + str(split_seq[mon])
        data.append(line)

    data.append("\n")
    data.append("BONDS")
    
    for j in range(1,DP):
        data.append(str(j) + " " + str(j + 1) + " CC")

    with open(filename, "w") as txt_file:
        for line in data:
            txt_file.write("".join(line) + "\n")
