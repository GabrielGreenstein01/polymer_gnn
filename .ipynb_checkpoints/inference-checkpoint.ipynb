# %%
import pandas as pd

# %%
# Take in dataframe and run inference pipeline
df = pd.read_parquet('inference/samples_one_replicate/0df1d0c39c1d4684a616a57b0851ab1c_rows_642032.parquet', engine='pyarrow')
df
# Out:
#                            ID  \
# 0       000000002516045_00001
# 1       000000002516047_00001
# 2       000000002516049_00001
# 3       000000002516051_00001
# 4       000000002516053_00001
# ...                       ...
# 642027  000000004973718_00001
# 642028  000000004973973_00001
# 642029  000000004973993_00001
# 642030  000000004974013_00001
# 642031  000000004974033_00001
#
#                                          mol_distribution  \
# 0       [0.06880176793451682, 0.036911532441588304, 0....
# 1       [0.06923435300951733, 0.0371436104609326, 0.49...
# 2       [0.0696724121837914, 0.03737862528552172, 0.55...
# 3       [0.0701160500260276, 0.037616633015520796, 0.6...
# 4       [0.07056537378533904, 0.0378576911891187, 0.66...
# ...                                                   ...
# 642027  [0.6406224024375871, 0.049098311819314684, 0.1...
# 642028  [0.5548110248045004, 0.19843409799695177, 0.06...
# 642029  [0.6030802338791228, 0.14932945175006906, 0.06...
# ...

# %%
# MON_SMILES_POLY, BOND_SMILES_POLY, DESCRIPTORS, hyperparameters, model, export results
class predict:
    def __init__(self, MON_SMILES_POLY, BOND_SMILES_POLY, DESCRIPTORS, hyperparameters, model, export results)
